# %% [markdown]
# <a href="https://colab.research.google.com/github/anamtasiddiquii/KNN--diabetes-Dataset/blob/main/knn_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/diabetes.zip')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Columns where 0 means missing
cols_with_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Replace 0 with NaN
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

df[cols_with_missing]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0      148.0           72.0           35.0      NaN  33.6
# 1       85.0           66.0           29.0      NaN  26.6
# 2      183.0           64.0            NaN      NaN  23.3
# 3       89.0           66.0           23.0     94.0  28.1
# 4      137.0           40.0           35.0    168.0  43.1
# ..       ...            ...            ...      ...   ...
# 763    101.0           76.0           48.0    180.0  32.9
# 764    122.0           70.0           27.0      NaN  36.8
# 765    121.0           72.0           23.0    112.0  26.2
# 766    126.0           60.0            NaN      NaN  30.1
# 767     93.0           70.0           31.0      NaN  30.4
#
# [768 rows x 5 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X= df.drop(columns=['Outcome'])
y=df['Outcome']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=20)

# %%
knn=KNNImputer(n_neighbors=3,weights='distance')
X_train_trf=knn.fit_transform(X_train)
X_test_trf=knn.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_trf)
X_test_scaled = scaler.transform(X_test_trf)

# %%
pd.DataFrame(X_train_trf,columns=X_train.columns)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            1.0    100.0           72.0      12.000000   70.000000  25.3
# 1            3.0    191.0           68.0      15.000000  130.000000  30.9
# 2            3.0     78.0           70.0      37.213918   56.707830  32.5
# 3           11.0    111.0           84.0      40.000000  154.542491  46.8
# 4            5.0    109.0           75.0      26.000000  296.798490  36.0
# ..           ...      ...            ...            ...         ...   ...
# 609          5.0     85.0           74.0      22.000000   61.004659  29.0
# 610          7.0    142.0           60.0      33.000000  190.000000  28.8
# 611          2.0    108.0           62.0      32.000000   56.000000  25.2
# 612          4.0    114.0           64.0      22.000000  160.399260  28.9
# 613          9.0    165.0           88.0      37.947197  173.789509  30.4
#
#      DiabetesPedigreeFunction   Age
# 0                       0.658  28.0
# ...

# %%
lr=LogisticRegression(random_state=42,max_iter=1000)
lr.fit(X_train_trf,y_train)
y_pred=lr.predict(X_test_trf)
accuracy_score(y_test,y_pred)
# Out:
# 0.7597402597402597
